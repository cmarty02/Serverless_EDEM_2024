# %% [markdown]
# #### Script: Dataflow Basics
#
# Description: Notebook where we will see the functioning of each transformation discussed during the theory.
#
# EDEM. Master Data Analytics<br>
# Professor: Javi Briones

# %% [markdown]
# ### Setup

# %%
# GCP Auth

# Local
# !gcloud auth application-default login

# Google Colab
# from google.colab import auth
# auth.authenticate_user()
# Out:
# "gcloud" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
# Install requirements
# !pip3 install "apache_beam[interactive]"
# Out:
# Collecting apache_beam[interactive]
#   Downloading apache_beam-2.53.0-cp39-cp39-win_amd64.whl.metadata (6.7 kB)
# Collecting crcmod<2.0,>=1.7 (from apache_beam[interactive])
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ---------------------------------------- 0.0/89.7 kB ? eta -:--:--
#      ------------------------------------ --- 81.9/89.7 kB 1.5 MB/s eta 0:00:01
#      ---------------------------------------- 89.7/89.7 kB 1.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting orjson<4,>=3.9.7 (from apache_beam[interactive])
#   Downloading orjson-3.9.12-cp39-none-win_amd64.whl.metadata (50 kB)
#      ---------------------------------------- 0.0/50.6 kB ? eta -:--:--
#      ---------------------------------------- 50.6/50.6 kB 2.7 MB/s eta 0:00:00
# Collecting dill<0.3.2,>=0.3.1.1 (from apache_beam[interactive])
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ---------------------------------------- 0.0/152.0 kB ? eta -:--:--
#      -------------------------------------- 152.0/152.0 kB 3.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting cloudpickle~=2.2.1 (from apache_beam[interactive])
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting fastavro<2,>=0.23.6 (from apache_beam[interactive])
#   Downloading fastavro-1.9.3-cp39-cp39-win_amd64.whl.metadata (5.7 kB)
# Collecting fasteners<1.0,>=0.3 (from apache_beam[interactive])
#   Downloading fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Collecting grpcio!=1.48.0,<2,>=1.33.1 (from apache_beam[interactive])
#   Downloading grpcio-1.60.0-cp39-cp39-win_amd64.whl.metadata (4.2 kB)
# Collecting hdfs<3.0.0,>=2.1.0 (from apache_beam[interactive])
#   Downloading hdfs-2.7.3.tar.gz (43 kB)
#      ---------------------------------------- 0.0/43.5 kB ? eta -:--:--
#      ---------------------------------------- 43.5/43.5 kB 2.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting httplib2<0.23.0,>=0.8 (from apache_beam[interactive])
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      ---------------------------------------- 0.0/96.9 kB ? eta -:--:--
#      ---------------------------------------- 96.9/96.9 kB 2.7 MB/s eta 0:00:00
# Collecting js2py<1,>=0.74 (from apache_beam[interactive])
#   Downloading Js2Py-0.74-py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#      ------------ --------------------------- 0.3/1.0 MB 6.5 MB/s eta 0:00:01
#      ------------------------------- -------- 0.8/1.0 MB 8.6 MB/s eta 0:00:01
#      ---------------------------------------- 1.0/1.0 MB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from apache_beam[interactive]) (4.20.0)
# Collecting jsonpickle<4.0.0,>=3.0.0 (from apache_beam[interactive])
#   Downloading jsonpickle-3.0.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting numpy<1.25.0,>=1.14.3 (from apache_beam[interactive])
#   Downloading numpy-1.24.4-cp39-cp39-win_amd64.whl.metadata (5.6 kB)
# Collecting objsize<0.7.0,>=0.6.1 (from apache_beam[interactive])
#   Downloading objsize-0.6.1-py3-none-any.whl (9.3 kB)
# Collecting packaging>=22.0 (from apache_beam[interactive])
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pymongo<5.0.0,>=3.8.0 (from apache_beam[interactive])
#   Downloading pymongo-4.6.1-cp39-cp39-win_amd64.whl.metadata (22 kB)
# Collecting proto-plus<2,>=1.7.1 (from apache_beam[interactive])
#   Downloading proto_plus-1.23.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<4.26.0,>=3.20.3 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from apache_beam[interactive]) (4.25.2)
# Collecting pydot<2,>=1.2.0 (from apache_beam[interactive])
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from apache_beam[interactive]) (2.8.2)
# Requirement already satisfied: pytz>=2018.3 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from apache_beam[interactive]) (2021.1)
# Collecting regex>=2020.6.8 (from apache_beam[interactive])
#   Downloading regex-2023.12.25-cp39-cp39-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      ---------------------------------------- 42.0/42.0 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from apache_beam[interactive]) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from apache_beam[interactive]) (4.9.0)
# Collecting zstandard<1,>=0.18.0 (from apache_beam[interactive])
#   Downloading zstandard-0.22.0-cp39-cp39-win_amd64.whl.metadata (3.0 kB)
# Collecting pyarrow<12.0.0,>=3.0.0 (from apache_beam[interactive])
#   Downloading pyarrow-11.0.0-cp39-cp39-win_amd64.whl (20.6 MB)
#      ---------------------------------------- 0.0/20.6 MB ? eta -:--:--
#       --------------------------------------- 0.5/20.6 MB 9.6 MB/s eta 0:00:03
#      - -------------------------------------- 1.0/20.6 MB 10.3 MB/s eta 0:00:02
#      -- ------------------------------------- 1.5/20.6 MB 10.5 MB/s eta 0:00:02
#      --- ------------------------------------ 2.0/20.6 MB 9.8 MB/s eta 0:00:02
#      ---- ----------------------------------- 2.5/20.6 MB 10.0 MB/s eta 0:00:02
#      ------ --------------------------------- 3.2/20.6 MB 10.8 MB/s eta 0:00:02
#      ------- -------------------------------- 3.7/20.6 MB 10.6 MB/s eta 0:00:02
#      -------- ------------------------------- 4.2/20.6 MB 10.8 MB/s eta 0:00:02
#      --------- ------------------------------ 4.7/20.6 MB 10.4 MB/s eta 0:00:02
#      ---------- ----------------------------- 5.2/20.6 MB 10.6 MB/s eta 0:00:02
#      ---------- ----------------------------- 5.6/20.6 MB 10.2 MB/s eta 0:00:02
#      ----------- ---------------------------- 6.2/20.6 MB 10.1 MB/s eta 0:00:02
#      ------------- -------------------------- 6.7/20.6 MB 10.2 MB/s eta 0:00:02
#      -------------- ------------------------- 7.4/20.6 MB 10.7 MB/s eta 0:00:02
#      --------------- ------------------------ 7.9/20.6 MB 10.5 MB/s eta 0:00:02
#      ---------------- ----------------------- 8.4/20.6 MB 10.4 MB/s eta 0:00:02
#      ----------------- ---------------------- 9.0/20.6 MB 10.7 MB/s eta 0:00:02
#      ------------------ --------------------- 9.6/20.6 MB 10.6 MB/s eta 0:00:02
#      ------------------- ------------------- 10.2/20.6 MB 10.8 MB/s eta 0:00:01
#      -------------------- ------------------ 10.7/20.6 MB 10.7 MB/s eta 0:00:01
#      --------------------- ----------------- 11.3/20.6 MB 10.9 MB/s eta 0:00:01
#      ---------------------- ---------------- 11.9/20.6 MB 10.9 MB/s eta 0:00:01
#      ----------------------- --------------- 12.5/20.6 MB 10.9 MB/s eta 0:00:01
#      ------------------------ -------------- 13.1/20.6 MB 10.9 MB/s eta 0:00:01
#      -------------------------- ------------ 13.8/20.6 MB 11.1 MB/s eta 0:00:01
#      --------------------------- ----------- 14.3/20.6 MB 11.3 MB/s eta 0:00:01
#      ---------------------------- ---------- 14.8/20.6 MB 11.3 MB/s eta 0:00:01
#      ----------------------------- --------- 15.4/20.6 MB 11.3 MB/s eta 0:00:01
#      ------------------------------ -------- 16.0/20.6 MB 11.7 MB/s eta 0:00:01
#      ------------------------------- ------- 16.5/20.6 MB 11.5 MB/s eta 0:00:01
#      -------------------------------- ------ 17.0/20.6 MB 11.5 MB/s eta 0:00:01
#      --------------------------------- ----- 17.5/20.6 MB 11.1 MB/s eta 0:00:01
#      ---------------------------------- ---- 18.1/20.6 MB 11.3 MB/s eta 0:00:01
#      ----------------------------------- --- 18.6/20.6 MB 11.5 MB/s eta 0:00:01
#      ------------------------------------ -- 19.2/20.6 MB 11.3 MB/s eta 0:00:01
#      ------------------------------------- - 19.7/20.6 MB 11.3 MB/s eta 0:00:01
#      --------------------------------------  20.2/20.6 MB 11.1 MB/s eta 0:00:01
#      --------------------------------------  20.6/20.6 MB 11.3 MB/s eta 0:00:01
#      --------------------------------------  20.6/20.6 MB 11.3 MB/s eta 0:00:01
#      --------------------------------------  20.6/20.6 MB 11.3 MB/s eta 0:00:01
#      ---------------------------------------- 20.6/20.6 MB 9.9 MB/s eta 0:00:00
# Collecting pyarrow-hotfix<1 (from apache_beam[interactive])
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting facets-overview<2,>=1.1.0 (from apache_beam[interactive])
#   Downloading facets_overview-1.1.1-py2.py3-none-any.whl.metadata (10 kB)
# Collecting google-cloud-dataproc<6,>=5.0.0 (from apache_beam[interactive])
#   Downloading google_cloud_dataproc-5.8.0-py2.py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: ipython<9,>=8 in c:\users\dell\appdata\roaming\python\python39\site-packages (from apache_beam[interactive]) (8.4.0)
# Requirement already satisfied: ipykernel<7,>=6 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from apache_beam[interactive]) (6.25.2)
# Collecting ipywidgets<9,>=8 (from apache_beam[interactive])
#   Downloading ipywidgets-8.1.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: jupyter-client!=6.1.13,<8.2.1,>=6.1.11 in c:\users\dell\appdata\roaming\python\python39\site-packages (from apache_beam[interactive]) (7.3.3)
# Collecting timeloop<2,>=1.0.2 (from apache_beam[interactive])
#   Downloading timeloop-1.0.2.tar.gz (2.9 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: nbformat<6,>=5.0.5 in c:\users\dell\appdata\roaming\python\python39\site-packages (from apache_beam[interactive]) (5.4.0)
# Requirement already satisfied: nbconvert<8,>=6.2.0 in c:\users\dell\appdata\roaming\python\python39\site-packages (from apache_beam[interactive]) (6.5.0)
# Collecting pandas!=1.5.0,!=1.5.1,<1.6,>=1.4.3 (from apache_beam[interactive])
#   Downloading pandas-1.5.3-cp39-cp39-win_amd64.whl (10.9 MB)
#      ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#      - -------------------------------------- 0.4/10.9 MB 11.2 MB/s eta 0:00:01
#      --- ------------------------------------ 0.9/10.9 MB 11.3 MB/s eta 0:00:01
#      ----- ---------------------------------- 1.5/10.9 MB 11.6 MB/s eta 0:00:01
#      ------- -------------------------------- 2.1/10.9 MB 10.9 MB/s eta 0:00:01
#      -------- ------------------------------- 2.4/10.9 MB 10.4 MB/s eta 0:00:01
#      ---------- ----------------------------- 3.0/10.9 MB 11.1 MB/s eta 0:00:01
#      ------------ --------------------------- 3.3/10.9 MB 10.5 MB/s eta 0:00:01
#      -------------- ------------------------- 3.9/10.9 MB 10.4 MB/s eta 0:00:01
#      --------------- ------------------------ 4.3/10.9 MB 10.2 MB/s eta 0:00:01
#      ----------------- ---------------------- 4.9/10.9 MB 10.3 MB/s eta 0:00:01
#      ------------------- -------------------- 5.3/10.9 MB 10.3 MB/s eta 0:00:01
#      --------------------- ------------------ 5.9/10.9 MB 10.4 MB/s eta 0:00:01
#      ----------------------- ---------------- 6.4/10.9 MB 10.3 MB/s eta 0:00:01
#      ------------------------ --------------- 6.8/10.9 MB 10.4 MB/s eta 0:00:01
#      --------------------------- ------------ 7.5/10.9 MB 10.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 8.0/10.9 MB 10.5 MB/s eta 0:00:01
#      ------------------------------- -------- 8.5/10.9 MB 10.3 MB/s eta 0:00:01
#      --------------------------------- ------ 9.1/10.9 MB 10.4 MB/s eta 0:00:01
#      ----------------------------------- ---- 9.6/10.9 MB 10.4 MB/s eta 0:00:01
#      ------------------------------------ -- 10.2/10.9 MB 10.5 MB/s eta 0:00:01
#      --------------------------------------  10.7/10.9 MB 10.6 MB/s eta 0:00:01
#      --------------------------------------  10.9/10.9 MB 10.4 MB/s eta 0:00:01
#      ---------------------------------------- 10.9/10.9 MB 9.9 MB/s eta 0:00:00
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-dataproc<6,>=5.0.0->apache_beam[interactive])
#   Downloading google_api_core-2.15.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting grpc-google-iam-v1<1.0.0dev,>=0.12.4 (from google-cloud-dataproc<6,>=5.0.0->apache_beam[interactive])
#   Downloading grpc_google_iam_v1-0.13.0-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting docopt (from hdfs<3.0.0,>=2.1.0->apache_beam[interactive])
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: six>=1.9.0 in c:\users\dell\appdata\roaming\python\python39\site-packages (from hdfs<3.0.0,>=2.1.0->apache_beam[interactive]) (1.15.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\dell\appdata\roaming\python\python39\site-packages (from httplib2<0.23.0,>=0.8->apache_beam[interactive]) (3.0.9)
# Requirement already satisfied: comm>=0.1.1 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from ipykernel<7,>=6->apache_beam[interactive]) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from ipykernel<7,>=6->apache_beam[interactive]) (1.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from ipykernel<7,>=6->apache_beam[interactive]) (5.3.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\dell\appdata\roaming\python\python39\site-packages (from ipykernel<7,>=6->apache_beam[interactive]) (0.1.3)
# Requirement already satisfied: nest-asyncio in c:\users\dell\appdata\roaming\python\python39\site-packages (from ipykernel<7,>=6->apache_beam[interactive]) (1.5.5)
# Requirement already satisfied: psutil in c:\users\dell\appdata\roaming\python\python39\site-packages (from ipykernel<7,>=6->apache_beam[interactive]) (5.9.1)
# Requirement already satisfied: pyzmq>=20 in c:\users\dell\appdata\roaming\python\python39\site-packages (from ipykernel<7,>=6->apache_beam[interactive]) (23.1.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\dell\appdata\roaming\python\python39\site-packages (from ipykernel<7,>=6->apache_beam[interactive]) (6.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from ipykernel<7,>=6->apache_beam[interactive]) (5.10.1)
# Requirement already satisfied: backcall in c:\users\dell\appdata\roaming\python\python39\site-packages (from ipython<9,>=8->apache_beam[interactive]) (0.2.0)
# Requirement already satisfied: decorator in c:\users\dell\appdata\roaming\python\python39\site-packages (from ipython<9,>=8->apache_beam[interactive]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\dell\appdata\roaming\python\python39\site-packages (from ipython<9,>=8->apache_beam[interactive]) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\dell\appdata\roaming\python\python39\site-packages (from ipython<9,>=8->apache_beam[interactive]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\dell\appdata\roaming\python\python39\site-packages (from ipython<9,>=8->apache_beam[interactive]) (3.0.29)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from ipython<9,>=8->apache_beam[interactive]) (2.17.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from ipython<9,>=8->apache_beam[interactive]) (49.2.1)
# Requirement already satisfied: stack-data in c:\users\dell\appdata\roaming\python\python39\site-packages (from ipython<9,>=8->apache_beam[interactive]) (0.2.0)
# Requirement already satisfied: colorama in c:\users\dell\appdata\roaming\python\python39\site-packages (from ipython<9,>=8->apache_beam[interactive]) (0.4.4)
# Collecting widgetsnbextension~=4.0.9 (from ipywidgets<9,>=8->apache_beam[interactive])
#   Downloading widgetsnbextension-4.0.9-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.9 (from ipywidgets<9,>=8->apache_beam[interactive])
#   Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tzlocal>=1.2 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from js2py<1,>=0.74->apache_beam[interactive]) (5.2)
# Collecting pyjsparser>=2.5.1 (from js2py<1,>=0.74->apache_beam[interactive])
#   Downloading pyjsparser-2.7.1.tar.gz (24 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: attrs>=22.2.0 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->apache_beam[interactive]) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->apache_beam[interactive]) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->apache_beam[interactive]) (0.31.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from jsonschema<5.0.0,>=4.0.0->apache_beam[interactive]) (0.14.1)
# Requirement already satisfied: entrypoints in c:\users\dell\appdata\roaming\python\python39\site-packages (from jupyter-client!=6.1.13,<8.2.1,>=6.1.11->apache_beam[interactive]) (0.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\dell\appdata\roaming\python\python39\site-packages (from nbconvert<8,>=6.2.0->apache_beam[interactive]) (4.11.1)
# Requirement already satisfied: bleach in c:\users\dell\appdata\roaming\python\python39\site-packages (from nbconvert<8,>=6.2.0->apache_beam[interactive]) (5.0.0)
# Requirement already satisfied: defusedxml in c:\users\dell\appdata\roaming\python\python39\site-packages (from nbconvert<8,>=6.2.0->apache_beam[interactive]) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\dell\appdata\roaming\python\python39\site-packages (from nbconvert<8,>=6.2.0->apache_beam[interactive]) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\dell\appdata\roaming\python\python39\site-packages (from nbconvert<8,>=6.2.0->apache_beam[interactive]) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\appdata\roaming\python\python39\site-packages (from nbconvert<8,>=6.2.0->apache_beam[interactive]) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\dell\appdata\roaming\python\python39\site-packages (from nbconvert<8,>=6.2.0->apache_beam[interactive]) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\dell\appdata\roaming\python\python39\site-packages (from nbconvert<8,>=6.2.0->apache_beam[interactive]) (0.6.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\dell\appdata\roaming\python\python39\site-packages (from nbconvert<8,>=6.2.0->apache_beam[interactive]) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\dell\appdata\roaming\python\python39\site-packages (from nbconvert<8,>=6.2.0->apache_beam[interactive]) (1.1.1)
# Requirement already satisfied: fastjsonschema in c:\users\dell\appdata\roaming\python\python39\site-packages (from nbformat<6,>=5.0.5->apache_beam[interactive]) (2.15.3)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo<5.0.0,>=3.8.0->apache_beam[interactive])
#   Downloading dnspython-2.4.2-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.24.0->apache_beam[interactive]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.24.0->apache_beam[interactive]) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.24.0->apache_beam[interactive]) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from requests<3.0.0,>=2.24.0->apache_beam[interactive]) (2021.5.30)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-dataproc<6,>=5.0.0->apache_beam[interactive])
#   Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting google-auth<3.0.dev0,>=2.14.1 (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-dataproc<6,>=5.0.0->apache_beam[interactive])
#   Downloading google_auth-2.26.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-dataproc<6,>=5.0.0->apache_beam[interactive])
#   Downloading grpcio_status-1.60.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\dell\appdata\roaming\python\python39\site-packages (from jedi>=0.16->ipython<9,>=8->apache_beam[interactive]) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel<7,>=6->apache_beam[interactive]) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\dell\appdata\roaming\python\python39\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel<7,>=6->apache_beam[interactive]) (304)
# Requirement already satisfied: wcwidth in c:\users\dell\appdata\roaming\python\python39\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<9,>=8->apache_beam[interactive]) (0.2.5)
# Requirement already satisfied: tzdata in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from tzlocal>=1.2->js2py<1,>=0.74->apache_beam[interactive]) (2023.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dell\appdata\roaming\python\python39\site-packages (from beautifulsoup4->nbconvert<8,>=6.2.0->apache_beam[interactive]) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\dell\appdata\roaming\python\python39\site-packages (from bleach->nbconvert<8,>=6.2.0->apache_beam[interactive]) (0.5.1)
# Requirement already satisfied: executing in c:\users\dell\appdata\roaming\python\python39\site-packages (from stack-data->ipython<9,>=8->apache_beam[interactive]) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\dell\appdata\roaming\python\python39\site-packages (from stack-data->ipython<9,>=8->apache_beam[interactive]) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\dell\appdata\roaming\python\python39\site-packages (from stack-data->ipython<9,>=8->apache_beam[interactive]) (0.2.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-dataproc<6,>=5.0.0->apache_beam[interactive]) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-dataproc<6,>=5.0.0->apache_beam[interactive]) (0.3.0)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.dev0,>=2.14.1->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-dataproc<6,>=5.0.0->apache_beam[interactive])
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\dell\appdata\local\programs\python\python39\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-dataproc<6,>=5.0.0->apache_beam[interactive]) (0.5.1)
# Downloading facets_overview-1.1.1-py2.py3-none-any.whl (22 kB)
# Downloading fastavro-1.9.3-cp39-cp39-win_amd64.whl (546 kB)
#    ---------------------------------------- 0.0/546.2 kB ? eta -:--:--
#    -------------------------------- ------ 460.8/546.2 kB 14.5 MB/s eta 0:00:01
#    --------------------------------------- 546.2/546.2 kB 11.4 MB/s eta 0:00:00
# Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Downloading google_cloud_dataproc-5.8.0-py2.py3-none-any.whl (307 kB)
#    ---------------------------------------- 0.0/307.8 kB ? eta -:--:--
#    ---------------------------------------- 307.8/307.8 kB 9.6 MB/s eta 0:00:00
# Downloading grpcio-1.60.0-cp39-cp39-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.7 MB 15.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.1/3.7 MB 11.1 MB/s eta 0:00:01
#    ------------------ --------------------- 1.7/3.7 MB 12.0 MB/s eta 0:00:01
#    ------------------------ --------------- 2.3/3.7 MB 12.3 MB/s eta 0:00:01
#    ------------------------------- -------- 2.9/3.7 MB 12.4 MB/s eta 0:00:01
#    ------------------------------------ --- 3.4/3.7 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.7 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 10.8 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.1-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.4 kB ? eta -:--:--
#    ---------------------------------------- 139.4/139.4 kB 8.1 MB/s eta 0:00:00
# Downloading jsonpickle-3.0.2-py3-none-any.whl (40 kB)
#    ---------------------------------------- 0.0/40.7 kB ? eta -:--:--
#    ---------------------------------------- 40.7/40.7 kB 1.9 MB/s eta 0:00:00
# Downloading numpy-1.24.4-cp39-cp39-win_amd64.whl (14.9 MB)
#    ---------------------------------------- 0.0/14.9 MB ? eta -:--:--
#    - -------------------------------------- 0.7/14.9 MB 13.9 MB/s eta 0:00:02
#    --- ------------------------------------ 1.4/14.9 MB 12.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.9/14.9 MB 11.9 MB/s eta 0:00:02
#    ------ --------------------------------- 2.4/14.9 MB 12.0 MB/s eta 0:00:02
#    ------- -------------------------------- 3.0/14.9 MB 11.8 MB/s eta 0:00:02
#    --------- ------------------------------ 3.6/14.9 MB 11.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 4.0/14.9 MB 11.6 MB/s eta 0:00:01
#    ------------ --------------------------- 4.6/14.9 MB 11.4 MB/s eta 0:00:01
#    ------------- -------------------------- 5.0/14.9 MB 11.1 MB/s eta 0:00:01
#    -------------- ------------------------- 5.6/14.9 MB 11.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 6.2/14.9 MB 11.3 MB/s eta 0:00:01
#    ------------------ --------------------- 6.7/14.9 MB 11.3 MB/s eta 0:00:01
#    ------------------- -------------------- 7.1/14.9 MB 11.4 MB/s eta 0:00:01
#    -------------------- ------------------- 7.7/14.9 MB 11.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.2/14.9 MB 11.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 8.8/14.9 MB 11.2 MB/s eta 0:00:01
#    ------------------------- -------------- 9.4/14.9 MB 11.5 MB/s eta 0:00:01
#    -------------------------- ------------- 9.9/14.9 MB 11.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 10.6/14.9 MB 11.3 MB/s eta 0:00:01
#    ------------------------------ --------- 11.2/14.9 MB 11.3 MB/s eta 0:00:01
#    ------------------------------- -------- 11.8/14.9 MB 11.5 MB/s eta 0:00:01
#    --------------------------------- ------ 12.4/14.9 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 12.8/14.9 MB 11.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.4/14.9 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------- -- 13.8/14.9 MB 11.3 MB/s eta 0:00:01
#    -------------------------------------- - 14.4/14.9 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  14.9/14.9 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  14.9/14.9 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 14.9/14.9 MB 10.2 MB/s eta 0:00:00
# Downloading orjson-3.9.12-cp39-none-win_amd64.whl (134 kB)
#    ---------------------------------------- 0.0/134.7 kB ? eta -:--:--
#    ---------------------------------------- 134.7/134.7 kB 7.8 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ---------------------------------------- 0.0/53.0 kB ? eta -:--:--
#    ---------------------------------------- 53.0/53.0 kB ? eta 0:00:00
# Downloading proto_plus-1.23.0-py3-none-any.whl (48 kB)
#    ---------------------------------------- 0.0/48.8 kB ? eta -:--:--
#    ---------------------------------------- 48.8/48.8 kB 2.4 MB/s eta 0:00:00
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading pymongo-4.6.1-cp39-cp39-win_amd64.whl (472 kB)
#    ---------------------------------------- 0.0/472.7 kB ? eta -:--:--
#    --------------------------------------  471.0/472.7 kB 14.9 MB/s eta 0:00:01
#    ---------------------------------------- 472.7/472.7 kB 9.8 MB/s eta 0:00:00
# Downloading regex-2023.12.25-cp39-cp39-win_amd64.whl (269 kB)
#    ---------------------------------------- 0.0/269.5 kB ? eta -:--:--
#    --------------------------------------- 269.5/269.5 kB 16.2 MB/s eta 0:00:00
# Downloading zstandard-0.22.0-cp39-cp39-win_amd64.whl (511 kB)
#    ---------------------------------------- 0.0/511.7 kB ? eta -:--:--
#    --------------------------------------  501.8/511.7 kB 15.4 MB/s eta 0:00:01
#    --------------------------------------- 511.7/511.7 kB 10.7 MB/s eta 0:00:00
# Downloading apache_beam-2.53.0-cp39-cp39-win_amd64.whl (5.1 MB)
#    ---------------------------------------- 0.0/5.1 MB ? eta -:--:--
#    ------ --------------------------------- 0.8/5.1 MB 17.0 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.4/5.1 MB 14.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.1/5.1 MB 12.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.1/5.1 MB 12.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.1/5.1 MB 12.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 2.1/5.1 MB 12.1 MB/s eta 0:00:01
#    -------------------- ------------------- 2.6/5.1 MB 7.2 MB/s eta 0:00:01
#    ------------------------ --------------- 3.1/5.1 MB 7.7 MB/s eta 0:00:01
#    ------------------------ --------------- 3.1/5.1 MB 7.7 MB/s eta 0:00:01
#    ------------------------ --------------- 3.1/5.1 MB 7.7 MB/s eta 0:00:01
#    ------------------------ --------------- 3.1/5.1 MB 7.7 MB/s eta 0:00:01
#    ------------------------ --------------- 3.1/5.1 MB 7.7 MB/s eta 0:00:01
#    ------------------------ --------------- 3.1/5.1 MB 7.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.7/5.1 MB 5.2 MB/s eta 0:00:01
#    -------------------------------- ------- 4.2/5.1 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------ --- 4.7/5.1 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  5.1/5.1 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 5.1/5.1 MB 5.8 MB/s eta 0:00:00
# Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#    ---------------------------------------- 0.0/300.4 kB ? eta -:--:--
#    ---------------------------------------- 300.4/300.4 kB 6.2 MB/s eta 0:00:00
# Downloading google_api_core-2.15.0-py3-none-any.whl (121 kB)
#    ---------------------------------------- 0.0/122.0 kB ? eta -:--:--
#    ---------------------------------------- 122.0/122.0 kB 7.0 MB/s eta 0:00:00
# Downloading grpc_google_iam_v1-0.13.0-py2.py3-none-any.whl (25 kB)
# Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl (214 kB)
#    ---------------------------------------- 0.0/214.9 kB ? eta -:--:--
#    ------------------------------------- - 204.8/214.9 kB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 214.9/214.9 kB 2.6 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ----------- ---------------------------- 0.6/2.3 MB 13.3 MB/s eta 0:00:01
#    ------------------- -------------------- 1.1/2.3 MB 11.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.6/2.3 MB 11.4 MB/s eta 0:00:01
#    ------------------------------------- -- 2.1/2.3 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 9.8 MB/s eta 0:00:00
# Downloading google_auth-2.26.2-py2.py3-none-any.whl (186 kB)
#    ---------------------------------------- 0.0/186.5 kB ? eta -:--:--
#    ---------------------------------------- 186.5/186.5 kB 5.7 MB/s eta 0:00:00
# Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl (228 kB)
#    ---------------------------------------- 0.0/228.7 kB ? eta -:--:--
#    --------------------------------------- 228.7/228.7 kB 13.7 MB/s eta 0:00:00
# Downloading grpcio_status-1.60.0-py3-none-any.whl (14 kB)
# Building wheels for collected packages: crcmod, dill, hdfs, timeloop, pyjsparser, docopt
#   Building wheel for crcmod (pyproject.toml): started
#   Building wheel for crcmod (pyproject.toml): finished with status 'done'
#   Created wheel for crcmod: filename=crcmod-1.7-py3-none-any.whl size=18869 sha256=3691c134a318dd1b7c6a71a95c2a286c0a866e456b47268752d4d90026333973
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\4a\6c\a6\ffdd136310039bf226f2707a9a8e6857be7d70a3fc061f6b36
#   Building wheel for dill (pyproject.toml): started
#   Building wheel for dill (pyproject.toml): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78667 sha256=b8a150718edb156541b570d14a353cad368da72ad5fb5a2624dc14d03d220181
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\4f\0b\ce\75d96dd714b15e51cb66db631183ea3844e0c4a6d19741a149
#   Building wheel for hdfs (pyproject.toml): started
#   Building wheel for hdfs (pyproject.toml): finished with status 'done'
#   Created wheel for hdfs: filename=hdfs-2.7.3-py3-none-any.whl size=34351 sha256=9bf30e010304858e41a7647217aec336fc37b9277deba4f47e1603e806840dbd
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\05\6f\21\aa8d233f90da3017b4ef7c61829589dc267402d376dd3efcf5
#   Building wheel for timeloop (pyproject.toml): started
#   Building wheel for timeloop (pyproject.toml): finished with status 'done'
#   Created wheel for timeloop: filename=timeloop-1.0.2-py3-none-any.whl size=3722 sha256=0a3d6d1d3962c42569130796ba71fa6f438566d487e0fcbe8eecb4cb76e7b71e
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\63\47\01\8e48745e2b92e8a78dc988d4e9404e4f10ccdcd207dc0cad69
#   Building wheel for pyjsparser (pyproject.toml): started
#   Building wheel for pyjsparser (pyproject.toml): finished with status 'done'
#   Created wheel for pyjsparser: filename=pyjsparser-2.7.1-py3-none-any.whl size=25989 sha256=3f48d1a508882e751d441e18035884a22d821fe8811506af8a4ffc9056afff3a
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\f0\70\61\f42dc45dcf0fbe8c495ce579b04730787081499bfb5b8bc60e
#   Building wheel for docopt (pyproject.toml): started
#   Building wheel for docopt (pyproject.toml): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13774 sha256=60a792f2777dc144bfc239e4717f32552b75b03934f8b17943935d7743264c05
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\70\4a\46\1309fc853b8d395e60bafaf1b6df7845bdd82c95fd59dd8d2b
# Successfully built crcmod dill hdfs timeloop pyjsparser docopt
# Installing collected packages: timeloop, pyjsparser, docopt, crcmod, zstandard, widgetsnbextension, rsa, regex, pydot, pyarrow-hotfix, proto-plus, packaging, orjson, objsize, numpy, jupyterlab-widgets, jsonpickle, httplib2, grpcio, googleapis-common-protos, fasteners, fastavro, dnspython, dill, cloudpickle, pymongo, pyarrow, pandas, js2py, hdfs, grpcio-status, google-auth, grpc-google-iam-v1, google-api-core, facets-overview, ipywidgets, apache_beam, google-cloud-dataproc
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.0
#     Uninstalling widgetsnbextension-3.6.0:
#       Successfully uninstalled widgetsnbextension-3.6.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.3
#     Uninstalling numpy-1.26.3:
#       Successfully uninstalled numpy-1.26.3
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 1.1.0
#     Uninstalling jupyterlab-widgets-1.1.0:
#       Successfully uninstalled jupyterlab-widgets-1.1.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.0
#     Uninstalling ipywidgets-7.7.0:
#       Successfully uninstalled ipywidgets-7.7.0
# Successfully installed apache_beam-2.53.0 cloudpickle-2.2.1 crcmod-1.7 dill-0.3.1.1 dnspython-2.4.2 docopt-0.6.2 facets-overview-1.1.1 fastavro-1.9.3 fasteners-0.19 google-api-core-2.15.0 google-auth-2.26.2 google-cloud-dataproc-5.8.0 googleapis-common-protos-1.62.0 grpc-google-iam-v1-0.13.0 grpcio-1.60.0 grpcio-status-1.60.0 hdfs-2.7.3 httplib2-0.22.0 ipywidgets-8.1.1 js2py-0.74 jsonpickle-3.0.2 jupyterlab-widgets-3.0.9 numpy-1.24.4 objsize-0.6.1 orjson-3.9.12 packaging-23.2 pandas-1.5.3 proto-plus-1.23.0 pyarrow-11.0.0 pyarrow-hotfix-0.6 pydot-1.4.2 pyjsparser-2.7.1 pymongo-4.6.1 regex-2023.12.25 rsa-4.9 timeloop-1.0.2 widgetsnbextension-4.0.9 zstandard-0.22.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scipy 1.7.1 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.24.4 which is incompatible.
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: C:\Users\DELL\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip

# %%
# Import Python Libraries
import logging
import apache_beam as beam
from apache_beam.runners.interactive.interactive_runner import InteractiveRunner
import apache_beam.runners.interactive.interactive_beam as ib

# %% [markdown]
# ### Beam Basics

# %% [markdown]
# <img src="../00_DocAux/.images/Beam_Pipeline.png" width="1000"/>

# %% [markdown]
# ##### 01 Understanding basic concepts: PCollection, PTransform & Pipeline Object

# %%
with beam.Pipeline(InteractiveRunner()) as p:

    (p   
        | "Read Text from a File" >> beam.io.ReadFromText('../00_DocAux/input_text.txt')
        | "FlatMap" >> beam.FlatMap(lambda z: z.split())
        | "map" >> beam.Map(lambda x: (x,1))
        | "resultado" >> beam.CombinePerKey(sum)
        | "Show content" >> beam.Map(print))
# Out:
# ('En', 1)
# ('un', 2)
# ('lugar', 1)
# ('de', 12)
# ('la', 1)
# ('Mancha,', 1)
# ('cuyo', 1)
# ('nombre', 1)
# ('no', 2)
# ('quiero', 1)
# ('acordarme,', 1)
# ('ha', 1)
# ('mucho', 1)
# ('tiempo', 1)
# ('que', 2)
# ('vivía', 1)
# ('hidalgo', 1)
# ('los', 5)
# ('lanza', 1)
# ('en', 1)
# ('astillero,', 1)
# ('adarga', 1)
# ('antigua,', 1)
# ('rocín', 1)
# ('flaco', 1)
# ('y', 2)
# ('galgo', 1)
# ('corredor.', 1)
# ('Una', 1)
# ('olla', 1)
# ('algo', 1)
# ('más', 3)
# ('vaca', 1)
# ('carnero,', 1)
# ('salpicón', 1)
# ('las', 3)
# ('noches,', 1)
# ('duelos', 1)
# ('quebrantos', 1)
# ('sábados,', 1)
# ('lantejas', 1)
# ('viernes,', 1)
# ('algún', 1)
# ('palomino', 1)
# ('añadidura', 1)
# ('domingos,', 1)
# ('consumían', 1)
# ('tres', 1)
# ('partes', 1)
# ('su', 2)
# ('hacienda.', 1)
# ('El', 1)
# ('resto', 1)
# ('della', 1)
# ('concluían', 1)
# ('sayo', 1)
# ('velarte,', 1)
# ('calzas', 1)
# ('velludo', 1)
# ('para', 1)
# ('fiestas', 1)
# ('con', 2)
# ('sus', 1)
# ('pantuflos', 1)
# ('lo', 2)
# ('mismo,', 1)
# ('días', 1)
# ('entre', 1)
# ('semana', 1)
# ('se', 1)
# ('honraba', 1)
# ('vellorí', 1)
# ('fino.', 1)

# %% [markdown]
# ##### 02 Understanding Core Transformations: DoFn & Map

# %%
# Map
def edem_map(element, num):
    return element * num

# DoFn
class edemDoFn(beam.DoFn):

    def __init__(self, num):
        self.num_ = num

    def process(self, element):
        yield element * self.num_

# Pipeline
with beam.Pipeline(InteractiveRunner()) as p:
  data = (
      p 
        | "Create a PCollection" >> beam.Create([1,2,3,4,5])
        | "Map" >> beam.Map(edem_map, num=2)
        | "DoFn" >> beam.ParDo(edemDoFn(4))
        | "Print" >> beam.Map(print)
  )
# Out:
# 8
# 16
# 24
# 32
# 40

# %%
# PTransform
class edem_PTransform(beam.PTransform):

    # Map
    def edem_map(element):
        return element * 2

    # DoFn
    class edemDoFn(beam.DoFn):

        def process(self, element, num):
            yield element * num
    
    def expand(self,PColl):
        
        PColl_ = (PColl 
            | "Map" >> beam.Map(lambda x: x * 2)
            | "ParDo" >> beam.ParDo(edemDoFn(), num=4)
            | "Print" >> beam.Map(print))
        
        yield PColl_

# Pipeline
with beam.Pipeline(InteractiveRunner()) as p:
    data = (
        p 
            | "Create a PCollection" >> beam.Create([1,2,3,4,5])
    )
    
    data | edem_PTransform() | "Print" >> beam.Map(print)
# Out:
# usage: ipykernel_launcher.py [-h] [--dataflow_endpoint DATAFLOW_ENDPOINT]
#                              [--project PROJECT] [--job_name JOB_NAME]
#                              [--staging_location STAGING_LOCATION]
#                              [--temp_location TEMP_LOCATION] [--region REGION]
#                              [--service_account_email SERVICE_ACCOUNT_EMAIL]
#                              [--no_auth]
#                              [--template_location TEMPLATE_LOCATION]
#                              [--label LABELS] [--update]
#                              [--transform_name_mapping TRANSFORM_NAME_MAPPING]
#                              [--enable_streaming_engine]
#                              [--dataflow_kms_key DATAFLOW_KMS_KEY]
#                              [--create_from_snapshot CREATE_FROM_SNAPSHOT]
#                              [--flexrs_goal {COST_OPTIMIZED,SPEED_OPTIMIZED}]
#                              [--dataflow_service_option DATAFLOW_SERVICE_OPTIONS]
#                              [--enable_hot_key_logging]
#                              [--enable_artifact_caching]
#                              [--impersonate_service_account IMPERSONATE_SERVICE_ACCOUNT]
#                              [--gcp_oauth_scope GCP_OAUTH_SCOPES]
# ipykernel_launcher.py: error: argument --flexrs_goal: invalid choice: 'c:\\Users\\DELL\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-267681si83ZPFwX0q.json' (choose from 'COST_OPTIMIZED', 'SPEED_OPTIMIZED')
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# File d:\Anaconda\Lib\argparse.py:1902, in ArgumentParser.parse_known_args(self, args, namespace)
#    1901 try:
# -> 1902     namespace, args = self._parse_known_args(args, namespace)
#    1903 except ArgumentError as err:
#
# File d:\Anaconda\Lib\argparse.py:2114, in ArgumentParser._parse_known_args(self, arg_strings, namespace)
#    2113     # consume the next optional and any arguments for it
# -> 2114     start_index = consume_optional(start_index)
#    2116 # consume any positionals following the last Optional
#
# File d:\Anaconda\Lib\argparse.py:2054, in ArgumentParser._parse_known_args.<locals>.consume_optional(start_index)
#    2053 for action, args, option_string in action_tuples:
# -> 2054     take_action(action, args, option_string)
#    2055 return stop
#
# File d:\Anaconda\Lib\argparse.py:1962, in ArgumentParser._parse_known_args.<locals>.take_action(action, argument_strings, option_string)
#    1961 seen_actions.add(action)
# -> 1962 argument_values = self._get_values(action, argument_strings)
#    1964 # error if this argument is not allowed with other previously
#    1965 # seen arguments, assuming that actions that use the default
#    1966 # value don't really count as "present"
#
# File d:\Anaconda\Lib\argparse.py:2497, in ArgumentParser._get_values(self, action, arg_strings)
#    2496     value = self._get_value(action, arg_string)
# -> 2497     self._check_value(action, value)
#    2499 # REMAINDER arguments convert all values, checking none
#
# File d:\Anaconda\Lib\argparse.py:2553, in ArgumentParser._check_value(self, action, value)
#    2552 msg = _('invalid choice: %(value)r (choose from %(choices)s)')
# -> 2553 raise ArgumentError(action, msg % args)
#
# ArgumentError: argument --flexrs_goal: invalid choice: 'c:\\Users\\DELL\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-267681si83ZPFwX0q.json' (choose from 'COST_OPTIMIZED', 'SPEED_OPTIMIZED')
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[9], line 30
#      25 data = (
#      26     p
#      27         | "Create a PCollection" >> beam.Create([1,2,3,4,5])
#      28 )
# ---> 30 data | edem_PTransform() | "Print" >> beam.Map(print)
#
# File d:\Anaconda\Lib\site-packages\apache_beam\transforms\ptransform.py:1110, in _NamedPTransform.__ror__(self, pvalueish, _unused)
#    1109 def __ror__(self, pvalueish, _unused=None):
# -> 1110   return self.transform.__ror__(pvalueish, self.label)
#
# File d:\Anaconda\Lib\site-packages\apache_beam\transforms\ptransform.py:596, in PTransform.__ror__(self, left, label)
#     595   # pylint: enable=wrong-import-order, wrong-import-position
# --> 596   p = pipeline.Pipeline('DirectRunner', PipelineOptions(sys.argv))
#     597 else:
#
# File d:\Anaconda\Lib\site-packages\apache_beam\pipeline.py:209, in Pipeline.__init__(self, runner, options, argv, display_data)
#     208 # Validate pipeline options
# --> 209 errors = PipelineOptionsValidator(self._options, runner).validate()
#     210 if errors:
#
# File d:\Anaconda\Lib\site-packages\apache_beam\options\pipeline_options_validator.py:149, in PipelineOptionsValidator.validate(self)
#     148   if 'validate' in cls.__dict__ and callable(cls.__dict__['validate']):
# --> 149     errors.extend(self.options.view_as(cls).validate(self))
#     150 return errors
#
# File d:\Anaconda\Lib\site-packages\apache_beam\options\pipeline_options.py:451, in PipelineOptions.view_as(self, cls)
#     430 """Returns a view of current object as provided PipelineOption subclass.
#     431
#     432 Example Usage::
#    (...)
#     449
#     450 """
# --> 451 view = cls(self._flags)
#     453 for option_name in view._visible_option_list():
#     454   # Initialize values of keys defined by a cls.
#     455   #
#    (...)
#     459   # backed by the same list across multiple views, and that any overrides of
#     460   # pipeline options already stored in _all_options are preserved.
#
# File d:\Anaconda\Lib\site-packages\apache_beam\options\pipeline_options.py:232, in PipelineOptions.__init__(self, flags, **kwargs)
#     230 # The _visible_options attribute will contain options that were recognized
#     231 # by the parser.
# --> 232 self._visible_options, _ = parser.parse_known_args(flags)
#     234 # self._all_options is initialized with overrides to flag values,
#     235 # provided in kwargs, and will store key-value pairs for options recognized
#     236 # by current PipelineOptions [sub]class and its views that may be created.
#    (...)
#     239 # as each new views are created.
#     240 # Users access this dictionary store via __getattr__ / __setattr__ methods.
#
# File d:\Anaconda\Lib\argparse.py:1904, in ArgumentParser.parse_known_args(self, args, namespace)
#    1903     except ArgumentError as err:
# -> 1904         self.error(str(err))
#    1905 else:
#
# File d:\Anaconda\Lib\site-packages\apache_beam\options\pipeline_options.py:136, in _BeamArgumentParser.error(self, message)
#     135   return
# --> 136 super().error(message)
#
# File d:\Anaconda\Lib\argparse.py:2630, in ArgumentParser.error(self, message)
#    2629 args = {'prog': self.prog, 'message': message}
# -> 2630 self.exit(2, _('%(prog)s: error: %(message)s\n') % args)
#
# File d:\Anaconda\Lib\argparse.py:2617, in ArgumentParser.exit(self, status, message)
#    2616     self._print_message(message, _sys.stderr)
# -> 2617 _sys.exit(status)
#
# SystemExit: 2
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File d:\Anaconda\Lib\site-packages\IPython\core\interactiveshell.py:2097, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2094 if exception_only:
#    2095     stb = ['An exception has occurred, use %tb to see '
#    2096            'the full traceback.\n']
# -> 2097     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2098                                                      value))
#    2099 else:
#    2101     def contains_exceptiongroup(val):
#
# File d:\Anaconda\Lib\site-packages\IPython\core\ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File d:\Anaconda\Lib\site-packages\IPython\core\ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File d:\Anaconda\Lib\site-packages\IPython\core\ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1433 else:
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File d:\Anaconda\Lib\site-packages\IPython\core\ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1323 mode = self.mode
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#    1330     return ListTB.get_exception_only(self, etype, value)
#
# File d:\Anaconda\Lib\site-packages\IPython\core\ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1164 def structured_traceback(
#    1165     self,
#    1166     etype: type,
#    (...)
#    1170     number_of_lines_of_context: int = 5,
#    1171 ):
#    1172     """Return a nice text document describing the traceback."""
# -> 1173     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                            tb_offset)
#    1176     colors = self.Colors  # just a shorthand + quicker name lookup
#    1177     colorsnormal = colors.Normal  # used a lot
#
# File d:\Anaconda\Lib\site-packages\IPython\core\ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1060 assert isinstance(tb_offset, int)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#    1067 skipped = 0
#
# File d:\Anaconda\Lib\site-packages\IPython\core\ultratb.py:1131, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1129 while cf is not None:
#    1130     try:
# -> 1131         mod = inspect.getmodule(cf.tb_frame)
#    1132         if mod is not None:
#    1133             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'

# %% [markdown]
# ##### 03 DoFn Lifecycle

# %%
from datetime import datetime
class DoFnLifeCycle(beam.DoFn):

  def now(self):
    self._now = datetime.now()
    return self._now

  def __init__(self):
    print("Constructor started at: %s" % self.now())

  def setup(self):
    print("worker started at: %s" % self.now())

  def start_bundle(self):
    print("bundle started at: %s" % self.now())

  def process(self, element):
    words = element.split()
    for word in words:
      print("Processing element: %s" % word)
      yield word.upper()

  def finish_bundle(self):
    print("bundle finished at: %s" % self.now())

  def teardown(self):
    print("worker finished at: %s" % self.now())

with beam.Pipeline(InteractiveRunner()) as p:
  input_data = (
      p 
        | "Reading the input file" >> beam.io.ReadFromText('../00_DocAux/input_text.txt')
        | "DoFn Life Cycle" >> beam.ParDo(DoFnLifeCycle())
  )

# %% [markdown]
# ##### 04 Transformations

# %%
# GroupByKey
with beam.Pipeline(InteractiveRunner()) as p:

    data = (p | "PCollection" >> beam.Create([('Spain', 'Valencia'), ('Spain','Barcelona'), ('France', 'Paris')]))

    (data 
        | "Combined" >> beam.GroupByKey()
        | "Print" >> beam.Map(print))

# %%
# CoGroupByKey
with beam.Pipeline(InteractiveRunner()) as p:

    p1 = p | "PCollection 01" >> beam.Create([('Spain', 'Valencia'), ('Spain','Barcelona'), ('France', 'Paris')])
    p2 = p | "PCollection 02" >> beam.Create([('Spain', 'Madrid'), ('Spain','Alicante'), ('France', 'Lyon')])

    data = ((p1,p2) | beam.CoGroupByKey())

    data | "Print" >> beam.Map(print)

# %%
# Combine
with beam.Pipeline(InteractiveRunner()) as p:

    data = (p | "PCollection" >> beam.Create([('User1', 1), ('User2', 5), ('User1', 7)]))

    (data 
        | "Combined" >> beam.CombinePerKey(sum)
        | "Print" >> beam.Map(print))

# %%
# Flatten
with beam.Pipeline(InteractiveRunner()) as p:

    p1 = p | "PCollection 01" >> beam.Create(['New York', 'Los Angeles', 'Miami', 'Chicago'])
    p2 = p | "Pcollection 02" >> beam.Create(['Madrid', 'Barcelona', 'Valencia', 'Malaga'])
    p3 = p | "Pcollection 03" >> beam.Create(['London','Manchester', 'Liverpool'])

    merged = ((p1,p2,p3)| beam.Flatten())

    merged | beam.Map(print)

# %%
# Partition
countries = ['Spain', 'USA', 'Switzerland']

def partition_fn(country,num_countries):
    return countries.index(country['country'])

with beam.Pipeline(InteractiveRunner()) as p:

        p1,p2,p3 = (
                p 
                | "PCollection" >> beam.Create([
                        {'country': 'Spain', 'city': 'Valencia'},
                        {'country': 'Spain', 'city': 'Barcelona'},
                        {'country': 'USA', 'city': 'New York'},
                        {'country': 'Switzerland', 'city': 'Zurich'},
                        {'country': 'Switzerland', 'city': 'Geneva'}  
                ])
                | "partition" >> beam.Partition(partition_fn, len(countries))
        )

        p3 | "PCollection for Spain" >> beam.Map(print)

# %% [markdown]
# ##### 05 Streaming

# %%
# PubSub
from apache_beam.options.pipeline_options import PipelineOptions

with beam.Pipeline(options=PipelineOptions(streaming=True)) as p:

    data = (p | "ReadFromPubSub" >> beam.io.ReadFromPubSub(subscription='projects/dataflow-1-411618/subscriptions/new_topic-sub'))

    data | beam.Map(print)
# Out:
# usage: ipykernel_launcher.py [-h] [--dataflow_endpoint DATAFLOW_ENDPOINT]
#                              [--project PROJECT] [--job_name JOB_NAME]
#                              [--staging_location STAGING_LOCATION]
#                              [--temp_location TEMP_LOCATION] [--region REGION]
#                              [--service_account_email SERVICE_ACCOUNT_EMAIL]
#                              [--no_auth]
#                              [--template_location TEMPLATE_LOCATION]
#                              [--label LABELS] [--update]
#                              [--transform_name_mapping TRANSFORM_NAME_MAPPING]
#                              [--enable_streaming_engine]
#                              [--dataflow_kms_key DATAFLOW_KMS_KEY]
#                              [--create_from_snapshot CREATE_FROM_SNAPSHOT]
#                              [--flexrs_goal {COST_OPTIMIZED,SPEED_OPTIMIZED}]
#                              [--dataflow_service_option DATAFLOW_SERVICE_OPTIONS]
#                              [--enable_hot_key_logging]
#                              [--enable_artifact_caching]
#                              [--impersonate_service_account IMPERSONATE_SERVICE_ACCOUNT]
#                              [--gcp_oauth_scope GCP_OAUTH_SCOPES]
# ipykernel_launcher.py: error: argument --flexrs_goal: invalid choice: 'c:\\Users\\DELL\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-26768jamV17We6l1J.json' (choose from 'COST_OPTIMIZED', 'SPEED_OPTIMIZED')
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# File d:\Anaconda\Lib\argparse.py:1902, in ArgumentParser.parse_known_args(self, args, namespace)
#    1901 try:
# -> 1902     namespace, args = self._parse_known_args(args, namespace)
#    1903 except ArgumentError as err:
#
# File d:\Anaconda\Lib\argparse.py:2114, in ArgumentParser._parse_known_args(self, arg_strings, namespace)
#    2113     # consume the next optional and any arguments for it
# -> 2114     start_index = consume_optional(start_index)
#    2116 # consume any positionals following the last Optional
#
# File d:\Anaconda\Lib\argparse.py:2054, in ArgumentParser._parse_known_args.<locals>.consume_optional(start_index)
#    2053 for action, args, option_string in action_tuples:
# -> 2054     take_action(action, args, option_string)
#    2055 return stop
#
# File d:\Anaconda\Lib\argparse.py:1962, in ArgumentParser._parse_known_args.<locals>.take_action(action, argument_strings, option_string)
#    1961 seen_actions.add(action)
# -> 1962 argument_values = self._get_values(action, argument_strings)
#    1964 # error if this argument is not allowed with other previously
#    1965 # seen arguments, assuming that actions that use the default
#    1966 # value don't really count as "present"
#
# File d:\Anaconda\Lib\argparse.py:2497, in ArgumentParser._get_values(self, action, arg_strings)
#    2496     value = self._get_value(action, arg_string)
# -> 2497     self._check_value(action, value)
#    2499 # REMAINDER arguments convert all values, checking none
#
# File d:\Anaconda\Lib\argparse.py:2553, in ArgumentParser._check_value(self, action, value)
#    2552 msg = _('invalid choice: %(value)r (choose from %(choices)s)')
# -> 2553 raise ArgumentError(action, msg % args)
#
# ArgumentError: argument --flexrs_goal: invalid choice: 'c:\\Users\\DELL\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-26768jamV17We6l1J.json' (choose from 'COST_OPTIMIZED', 'SPEED_OPTIMIZED')
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[5], line 4
#       2 from apache_beam.options.pipeline_options import PipelineOptions
# ----> 4 with beam.Pipeline(options=PipelineOptions(streaming=True)) as p:
#       6     data = (p | "ReadFromPubSub" >> beam.io.ReadFromPubSub(subscription='projects/dataflow-1-411618/subscriptions/new_topic-sub'))
#
# File d:\Anaconda\Lib\site-packages\apache_beam\pipeline.py:209, in Pipeline.__init__(self, runner, options, argv, display_data)
#     208 # Validate pipeline options
# --> 209 errors = PipelineOptionsValidator(self._options, runner).validate()
#     210 if errors:
#
# File d:\Anaconda\Lib\site-packages\apache_beam\options\pipeline_options_validator.py:149, in PipelineOptionsValidator.validate(self)
#     148   if 'validate' in cls.__dict__ and callable(cls.__dict__['validate']):
# --> 149     errors.extend(self.options.view_as(cls).validate(self))
#     150 return errors
#
# File d:\Anaconda\Lib\site-packages\apache_beam\options\pipeline_options.py:451, in PipelineOptions.view_as(self, cls)
#     430 """Returns a view of current object as provided PipelineOption subclass.
#     431
#     432 Example Usage::
#    (...)
#     449
#     450 """
# --> 451 view = cls(self._flags)
#     453 for option_name in view._visible_option_list():
#     454   # Initialize values of keys defined by a cls.
#     455   #
#    (...)
#     459   # backed by the same list across multiple views, and that any overrides of
#     460   # pipeline options already stored in _all_options are preserved.
#
# File d:\Anaconda\Lib\site-packages\apache_beam\options\pipeline_options.py:232, in PipelineOptions.__init__(self, flags, **kwargs)
#     230 # The _visible_options attribute will contain options that were recognized
#     231 # by the parser.
# --> 232 self._visible_options, _ = parser.parse_known_args(flags)
#     234 # self._all_options is initialized with overrides to flag values,
#     235 # provided in kwargs, and will store key-value pairs for options recognized
#     236 # by current PipelineOptions [sub]class and its views that may be created.
#    (...)
#     239 # as each new views are created.
#     240 # Users access this dictionary store via __getattr__ / __setattr__ methods.
#
# File d:\Anaconda\Lib\argparse.py:1904, in ArgumentParser.parse_known_args(self, args, namespace)
#    1903     except ArgumentError as err:
# -> 1904         self.error(str(err))
#    1905 else:
#
# File d:\Anaconda\Lib\site-packages\apache_beam\options\pipeline_options.py:136, in _BeamArgumentParser.error(self, message)
#     135   return
# --> 136 super().error(message)
#
# File d:\Anaconda\Lib\argparse.py:2630, in ArgumentParser.error(self, message)
#    2629 args = {'prog': self.prog, 'message': message}
# -> 2630 self.exit(2, _('%(prog)s: error: %(message)s\n') % args)
#
# File d:\Anaconda\Lib\argparse.py:2617, in ArgumentParser.exit(self, status, message)
#    2616     self._print_message(message, _sys.stderr)
# -> 2617 _sys.exit(status)
#
# SystemExit: 2
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py:2121, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2118 if exception_only:
#    2119     stb = ['An exception has occurred, use %tb to see '
#    2120            'the full traceback.\n']
# -> 2121     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2122                                                      value))
#    2123 else:
#    2125     def contains_exceptiongroup(val):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1433 else:
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1323 mode = self.mode
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#    1330     return ListTB.get_exception_only(self, etype, value)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1164 def structured_traceback(
#    1165     self,
#    1166     etype: type,
#    (...)
#    1170     number_of_lines_of_context: int = 5,
#    1171 ):
#    1172     """Return a nice text document describing the traceback."""
# -> 1173     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                            tb_offset)
#    1176     colors = self.Colors  # just a shorthand + quicker name lookup
#    1177     colorsnormal = colors.Normal  # used a lot
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1060 assert isinstance(tb_offset, int)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#    1067 skipped = 0
#
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py:1131, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1129 while cf is not None:
#    1130     try:
# -> 1131         mod = inspect.getmodule(cf.tb_frame)
#    1132         if mod is not None:
#    1133             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'

# %%
# !pip install google-cloud-PubSub
# Out:
# Collecting google-cloud-PubSub
#   Obtaining dependency information for google-cloud-PubSub from https://files.pythonhosted.org/packages/1e/5f/0d7fb021e4e5a0da2fc6fdfe7cb89e4f9c14f832c34ea2af8c4834c3c7fd/google_cloud_pubsub-2.19.0-py2.py3-none-any.whl.metadata
#   Downloading google_cloud_pubsub-2.19.0-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting grpcio<2.0dev,>=1.51.3 (from google-cloud-PubSub)
#   Obtaining dependency information for grpcio<2.0dev,>=1.51.3 from https://files.pythonhosted.org/packages/6a/b9/f94bea4c6f0e322a239f7ba66ba3b0ce766d1c6a2d50055f7c8acf0fba38/grpcio-1.60.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading grpcio-1.60.0-cp311-cp311-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0 in d:\anaconda\lib\site-packages (from google-cloud-PubSub) (1.34.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in d:\anaconda\lib\site-packages (from google-cloud-PubSub) (1.23.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in d:\anaconda\lib\site-packages (from google-cloud-PubSub) (3.20.3)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in d:\anaconda\lib\site-packages (from google-cloud-PubSub) (0.13.0)
# Requirement already satisfied: grpcio-status>=1.33.2 in d:\anaconda\lib\site-packages (from google-cloud-PubSub) (1.48.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in d:\anaconda\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-PubSub) (1.62.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in d:\anaconda\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-PubSub) (2.26.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in d:\anaconda\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-PubSub) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\anaconda\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-PubSub) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anaconda\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-PubSub) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anaconda\lib\site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-PubSub) (4.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-PubSub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-PubSub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-PubSub) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-PubSub) (2023.11.17)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-PubSub) (0.4.8)
# Downloading google_cloud_pubsub-2.19.0-py2.py3-none-any.whl (265 kB)
#    ---------------------------------------- 0.0/265.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/265.3 kB ? eta -:--:--
#    ------------- -------------------------- 92.2/265.3 kB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 256.0/265.3 kB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 265.3/265.3 kB 1.8 MB/s eta 0:00:00
# Downloading grpcio-1.60.0-cp311-cp311-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.2/3.7 MB 5.0 MB/s eta 0:00:01
#    ------ --------------------------------- 0.6/3.7 MB 7.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.1/3.7 MB 8.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.6/3.7 MB 8.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.1/3.7 MB 9.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.6/3.7 MB 9.3 MB/s eta 0:00:01
#    --------------------------------- ------ 3.1/3.7 MB 9.3 MB/s eta 0:00:01
#    -------------------------------------- - 3.5/3.7 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.7 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 8.7 MB/s eta 0:00:00
# Installing collected packages: grpcio, google-cloud-PubSub
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.48.2
#     Uninstalling grpcio-1.48.2:
#       Successfully uninstalled grpcio-1.48.2
# Successfully installed google-cloud-PubSub-2.19.0 grpcio-1.60.0
